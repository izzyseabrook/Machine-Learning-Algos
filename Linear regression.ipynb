# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("ex1data1.txt", header=None)

# %%
data.head()
# Out:
#         0        1
# 0  6.1101  17.5920
# 1  5.5277   9.1302
# 2  8.5186  13.6620
# 3  7.0032  11.8540
# 4  5.8598   6.8233

# %%
x=data.loc[:,0]
y=data.loc[:,1]

# %%
m=y.size

# %%
plt.scatter(X.loc[:,1],y)
plt.xlabel("Proift in $10,000s")
plt.ylabel("Population of City in 10,000s")
plt.show()

# %%
X=pd.DataFrame(np.ones(m))
X[1]=x

# %%
theta=np.zeros((2,1))
iterations=1500

alpha=0.01

# %%
def compute_cost(X, y, theta):
    m=y.size
    J=0.
    dPower=0
#print(m)
    for i in range(0,m):
        one=theta[0,0]*X[0][i]
        one=one.sum(axis=0)
        two=theta[1,0]*X[1][i]
        two=two.sum(axis=0)
        h=one+two
       # print(h)
        dsquare=(h-y[i])**2
        dPower=dPower+dsquare
       # print("here",dsquare)
    J=dPower/(2*m)
    return J
        
compute_cost(X,y,theta)
# Out:
# 32.072733877455654

# %%
new_theta=np.zeros([2,1])
new_theta[0]=-1.
new_theta[1]=2.
print(new_theta.shape)
compute_cost(X,y,new_theta)
#theta[1]
#y.shape
# Out:
# (2, 1)
# 54.242455082012377

# %%
thing1=(theta[0]+theta[1]*X[:][1])-y
#np.array(np.transpose(X)*thing1)
thing=np.sum(np.array(np.transpose(X)*thing1),axis=1, keepdims=True)
print(thing.shape)
# Out:
# (2, 1)

# %%
#integer bug here
def gradientDescent(X,y,theta,alpha,num_iters):
    m=y.size
    J_history=[]
    for i in range(0,num_iters):
        thing1=(theta[0]+theta[1]*X[:][1])-y
        thing=np.sum(np.array(np.transpose(X)*thing1),axis=1, keepdims=True)  
        theta+=-(alpha/m)*thing
        J_hist=compute_cost(X,y,theta)
        J_history.append(J_hist)
    return([theta,J_history])

test=gradientDescent(X,y,theta,alpha,iterations)
print(test)
# Out:
# [array([[-3.63029144],
# ...

# %%
test[0]
# Out:
# array([[-3.63029144],
#        [ 1.16636235]])

# %%
plt.scatter(X.loc[:,1], y)
plt.plot(X.loc[:,1],theta[0]+theta[1]*X[:][1])
plt.show()
